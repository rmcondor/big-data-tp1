# %% [markdown]
# # Curso de Big Data
#
# ## Trabajo Práctico 1 - Parte 2

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar bien comentado (utilizando #) para que el código sea fácil de entender por sus compañeros y profesores.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Miércoles 4 de octubre a las 23:59hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub con el mensaje “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 - Parte 1 deben estar dentro de esa carpeta.
# - También deben completar el link de su repositorio -para que pueda ser clonado y corregido- en la siguiente google sheet: https://docs.google.com/spreadsheets/d/11nJY1Frgla45sTgsPiSeOZM9iBM-XRWh/edit?usp=sharing&ouid=105815768529474116534&rtpof=true&sd=true
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No completen la google sheet hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar. Debido a que se pueden tomar hasta 3 días de extensión a lo largo del curso, no se  corregirán sus tareas hasta no ver el link en la google sheet.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.

# %% [markdown]
# ### Ejercicio 1
# Usando la API de Mercado Libre, obtener los ítems de una consulta de búsqueda. Pueden buscar cualquier producto de su interés.

# %%
# Asegurarse que tienes instalado las siguientes librerías
#!pip install requests 
#!pip install beautifulsoup4
#!pip install pandas

# %%
# Importamos las librerías necesarias
import requests
import pandas as pd

# %% [markdown]
# #### Consulta de búsqueda
# Ahora vamos a obtener los ítems de consulta de búsqueda usando la API de Mercado Libre. Buscaremos **auriculares inalámbricos**. Como estamos interesados en obtener resultados para Argentina, usaremos el código MLA para _site_.

# %%
busqueda = "auriculares inalambricos"
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", busqueda.replace(" ", "%20"))

# Hacemos el pedido o request y obtenemos la response
response = requests.request("GET", url)

# %%
#Guardamos el resultado (response) en un diccionario (.json)
data = response.json()

# %%
# Con las key de este diccionario podemos crear la base de datos.

# Veamos cuantos resultados tenemos:
print('Obs:', len(data.get('results', [])))
# Out:
# Obs: 50

# %% [markdown]
# ### Ejercicio 2
# Guarden los precios de los ítems obtenidos en un dataframe y calculen el precio promedio, el mínimo y el máximo.

# %% [markdown]
# #### Creación de dataframe y exportar a csv file

# %%
# Creamos objectos vacíos que llenaremos con toda la información relevante
product_ids = []
product_names = []
product_prices = []
product_links = []

# %%
# Iteramos y obtenemos la información
for result in data.get('results', []):
    product_id = result.get('id')
    product_name = result.get('title')
    product_price = result.get('price')
    product_link = result.get('permalink')
    
    # Append
    product_ids.append(product_id)
    product_names.append(product_name)
    product_prices.append(product_price)
    product_links.append(product_link)

# %%
# Creamos la dataframe
cleandata =   pd.DataFrame({
            'id': product_ids,
            'product': product_names,
            'price': product_prices,
            'link': product_links
            })

# %%
# Previsualizamos
cleandata.to_csv('clean_product_data.csv', index=False) #Exportamos a CSV
cleandata
# Out:
#                id                                            product  \
# 0   MLA1382011825  Audífonos Inalámbricos Con Cancelacion De Ruid...
# 1   MLA1100208917  Auriculares Bluetooth In-ear Gamer F9-5 Negro ...
# 2   MLA1366406419  Apple AirPods Pro (2ª Generación) - Distribuid...
# 3   MLA1449085246          Auriculares In-ear Inalámbricos A6s Negro
# 4   MLA1479772226  Auriculares In-ear Gamer Inalámbricos Fan Pro ...
# 5   MLA1293265833  Auriculares In-ear Inalámbricos Bluetooth F9-5...
# 6   MLA1368195865  Shenzhen Yihaotong Technology Genérica Bluetoo...
# 7   MLA1373479777  Dongguan Liesheng Electronic Technology Xiaomi...
# 8   MLA1251731657  Auriculares F95  In-ear Inalámbricos Alpina Po...
# 9   MLA1411030020  Auriculares In-ear Gamer Inalámbricos Tws F9-5...
# 10  MLA1439029838  Auriculares Inalambricos A8s Alpina Touch 25 H...
# 11  MLA1341742901  Auriculares In-ear Inalámbricos Hifuture Tws C...
# 12  MLA1375059343  Auriculares Bluetooth Inalámbricos Lenovo Lp40...
# 13  MLA1322219423  Auriculares In-ear Inalámbricos Alpina Bluetoo...
# 14  MLA1500422588  Auriculares In-ear Inalámbricos Xiaomi Redmi A...
# 15  MLA1214572841  Auriculares Inalámbricos Jbl Tune 510bt Jblt51...
# 16  MLA1449151456  Auriculares Motorola Motobuds 085 Bluetooth Ip...
# 17  MLA1374933441  Auriculares Inalámbricos Jbl Tune 510bt Jblt51...
# 18  MLA1388837527  Audifonos Jbl Tune 770 Bt Headphone Noise Canc...
# 19  MLA1151461598       Auriculares Inalámbricos Aiwa Aw-bt301 Negro
# 20  MLA1387197843  Auriculares In-ear Gamer Inalámbricos Xiaomi R...
# 21  MLA1439956034  Auriculares In-ear Inalámbricos Hifuture Tws C...
# 22  MLA1135091651  Auriculares In-ear Gamer Inalámbricos Xiaomi R...
# 23  MLA1521381780  Auriculares Inalámbricos Xiaomi Redmi Buds Ess...
# 24  MLA1484037278  Shenzhen Yihaotong Technology Genérica Bluetoo...
# 25   MLA923717599  Auriculares In-ear Inalámbricos Noga Ng-btwins...
# 26  MLA1481467680  Auriculares In-ear Gamer Inalámbricos Haylou G...
# 27  MLA1372532175  Auricular Inalámbrico Orejas De Gato Bluetooth...
# 28  MLA1133413113                            Genérica F9 - Negro - 1
# 29  MLA1382289759  Auriculares In-ear Inalámbricos Xiaomi Redmi B...
# 30  MLA1416607252  Auriculares In-ear Gamer Inalámbricos Haylou G...
# 31  MLA1500410986  Auriculares In-ear Gamer Inalámbricos Xiaomi R...
# 32  MLA1100359664          Shenzhen Soundsoul Soundpeats Mac - Negro
# 33  MLA1387102958                  Apple AirPods Pro (2ª Generación)
# 34  MLA1401645668  Haylou Gt1 2022 Audífonos In-ear Inalámbricos ...
# 35   MLA918184567  Auriculares In-ear Gamer Inalámbricos Soundpea...
# 36   MLA920534744  Auriculares In-ear Gamer Inalámbricos Soundpea...
# 37  MLA1394848118  Auriculares In-ear Gamer Inalámbricos Haylou G...
# 38  MLA1376848677  Auriculares F10 Pro Inalambricos Superior F9-5...
# 39  MLA1168341253  Auriculares Inalámbricos Bluetooth Mipods A6s ...
# 40  MLA1146909496  Auriculares Inalámbricos Xiaomi Redmi Buds 3 L...
# 41  MLA1172498468  Auriculares Bluetooth M10 Pro Superior F9-5 Ca...
# 42  MLA1159892259  Dongguan Hele Electronics Qcy True Wireless Ea...
# 43  MLA1391623598  Auriculares In-ear Inalámbricos Jbl Tune 130nc...
# 44  MLA1439026738  Auricular Celular Manos Libres Vincha Inalambr...
# 45  MLA1377574477  Auriculares In-ear Gamer Inalámbricos Soundpea...
# 46  MLA1124812999  Auriculares In-ear Inalambricos Sony Wf-c500 C...
# 47  MLA1519602758  Audífonos Inalámbricos Lenovo Lp5 Bluetooth 5....
# 48  MLA1387970401  Auriculares Bluetooth Para Apple iPhone 11 12 ...
# 49  MLA1114417439  Auriculares In-ear Inalámbricos Sony 1000x Ser...
#
#         price                                               link
# 0    31999.00  https://www.mercadolibre.com.ar/audifonos-inal...
# 1     2998.00  https://www.mercadolibre.com.ar/auriculares-bl...
# 2   209999.00  https://www.mercadolibre.com.ar/apple-airpods-...
# 3     2969.00  https://www.mercadolibre.com.ar/auriculares-in...
# 4     3611.16  https://www.mercadolibre.com.ar/auriculares-in...
# 5     3449.00  https://www.mercadolibre.com.ar/auriculares-in...
# 6     3032.00  https://www.mercadolibre.com.ar/shenzhen-yihao...
# 7    13655.00  https://www.mercadolibre.com.ar/dongguan-liesh...
# 8     3900.00  https://www.mercadolibre.com.ar/auriculares-f9...
# 9     3056.00  https://www.mercadolibre.com.ar/auriculares-in...
# 10    4501.00  https://www.mercadolibre.com.ar/auriculares-in...
# 11   19999.00  https://www.mercadolibre.com.ar/auriculares-in...
# 12   13099.00  https://www.mercadolibre.com.ar/auriculares-bl...
# 13    3491.00  https://www.mercadolibre.com.ar/auriculares-in...
# 14   12500.00  https://www.mercadolibre.com.ar/auriculares-in...
# 15   44346.00  https://www.mercadolibre.com.ar/auriculares-in...
# 16   22879.12  https://www.mercadolibre.com.ar/auriculares-mo...
# 17   37936.00  https://www.mercadolibre.com.ar/auriculares-in...
# 18   61799.00  https://www.mercadolibre.com.ar/audifonos-jbl-...
# 19   19333.00  https://www.mercadolibre.com.ar/auriculares-in...
# 20   55999.00  https://www.mercadolibre.com.ar/auriculares-in...
# 21   19999.00  https://www.mercadolibre.com.ar/auriculares-in...
# 22   14299.00  https://www.mercadolibre.com.ar/auriculares-in...
# 23   12400.00  https://www.mercadolibre.com.ar/auriculares-in...
# 24    3163.00  https://www.mercadolibre.com.ar/shenzhen-yihao...
# 25    7810.73  https://www.mercadolibre.com.ar/auriculares-in...
# 26   15750.00  https://www.mercadolibre.com.ar/auriculares-in...
# 27    7713.00  https://www.mercadolibre.com.ar/auricular-inal...
# 28    2962.00  https://www.mercadolibre.com.ar/generica-f9-ne...
# 29   15699.00  https://www.mercadolibre.com.ar/auriculares-in...
# 30   18122.00  https://www.mercadolibre.com.ar/auriculares-in...
# 31   11930.00  https://www.mercadolibre.com.ar/auriculares-in...
# 32   22803.00  https://www.mercadolibre.com.ar/shenzhen-sound...
# 33  178214.00  https://www.mercadolibre.com.ar/apple-airpods-...
# 34   15489.00  https://www.mercadolibre.com.ar/haylou-gt1-202...
# 35   25653.00  https://www.mercadolibre.com.ar/auriculares-in...
# 36   25653.00  https://www.mercadolibre.com.ar/auriculares-in...
# 37   17401.00  https://www.mercadolibre.com.ar/auriculares-in...
# 38    5391.00  https://www.mercadolibre.com.ar/auriculares-f1...
# 39    2950.00  https://articulo.mercadolibre.com.ar/MLA-11683...
# 40   21071.00  https://articulo.mercadolibre.com.ar/MLA-11469...
# 41    4891.00  https://articulo.mercadolibre.com.ar/MLA-11724...
# 42   19899.00  https://www.mercadolibre.com.ar/dongguan-hele-...
# 43   59999.00  https://www.mercadolibre.com.ar/auriculares-in...
# 44    4259.29  https://www.mercadolibre.com.ar/auricular-celu...
# 45   19545.00  https://www.mercadolibre.com.ar/auriculares-in...
# 46   52999.00  https://www.mercadolibre.com.ar/auriculares-in...
# 47   11849.21  https://www.mercadolibre.com.ar/audifonos-inal...
# 48    3314.00  https://www.mercadolibre.com.ar/auriculares-bl...
# 49  109999.00  https://www.mercadolibre.com.ar/auriculares-in...

# %% [markdown]
# #### Algunos descriptivos sobre el precio

# %%
print("Precio mínimo:", cleandata['price'].min(), "ARS")
print("Precio mediano:", cleandata['price'].median(), "ARS")
print("Precio promedio:", cleandata['price'].mean(), "ARS")
print("Precio máximo:", cleandata['price'].max(), "ARS")
# Out:
# Precio mínimo: 2950.0 ARS
# Precio mediano: 14894.0 ARS
# Precio promedio: 26115.5502 ARS
# Precio máximo: 209999.0 ARS

# %% [markdown]
# #### Ejercicio 3
# Armen un histograma de los precios. ¿Ven algún <i>outlier<i>?
# Nota: pueden usar la librería de Matplotlib o la de Pandas.
